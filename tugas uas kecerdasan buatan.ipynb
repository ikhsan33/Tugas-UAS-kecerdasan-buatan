# %%
from sklearn import tree 
clf = tree.DecisionTreeClassifier()
X = [[170, 67, 25], [180, 60, 30], [150, 45, 20], [140, 40, 17]] 
#[tinggi, berat badan, umur]
Y = ['Pria', 'Pria', 'Wanita', 'Wanita'] 
# jenis yang akan di labelkan
clf = clf.fit(X, Y)
prediction = clf.predict([[173, 67, 23]]) 
# Model Data yang digunakan 
print(prediction)
nama = ['ikhsan nugraha']
kelas = ['181011401977']
tugas = ['Syarat UAS kecerdasan buatan']
print(nama,kelas,tugas)
# Out:
# ['Pria']
# ['ikhsan nugraha'] ['181011401977'] ['Syarat UAS kecerdasan buatan']
